# %%
import csv
row_list = [['Semester','Student','Books'],
           [1,36,31],
           [2,28,29],
           [3,35,34],
           [4,39,35],
           [5,30,29],
           [6,30,30],
           [7,31,30],
           [8,38,38],
           [9,36,34],
           [10,38,33],
           [11,29,29],
           [12,26,26]]

with open('book_predict.csv','w',newline='') as file:
    writer = csv.writer(file)
    writer.writerows(row_list)

with open('book_predict.csv') as File:
    reader = csv.reader(File, delimiter=',', quotechar=',',
                        quoting=csv.QUOTE_MINIMAL)
    for row in reader:
        print(row)
    

# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn-whitegrid')
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression

df = pd.read_csv('book_predict.csv')
plt.scatter(df['Student'],df['Books'])
plt.ylabel('Number of books sold')
plt.xlabel('Number of registered students')

slope, intercept, r_value, p_value, std_err = stats.linregress(df['Student'],df['Books'])

line = slope*(df['Student'])+intercept
plt.plot(df['Student'], line, 'r', label='y={:.2f}x+{:.2f}'.format(slope,intercept))
plt.legend(loc='lower right')

plt.show()

print(np.corrcoef(df['Student'],df['Books']))

X = df['Student'].values.reshape(-1,1)
y = df['Student']

model = LinearRegression().fit(X,y)
X_new = np.array([[5,30]]).reshape(-1,1)
model.predict(X_new)
# Out:
# ['Semester', 'Student', 'Books']
# ['1', '36', '31']
# ['2', '28', '29']
# ['3', '35', '34']
# ['4', '39', '35']
# ['5', '30', '29']
# ['6', '30', '30']
# ['7', '31', '30']
# ['8', '38', '38']
# ['9', '36', '34']
# ['10', '38', '33']
# ['11', '29', '29']
# ['12', '26', '26']
# [[1.        0.8997002]
#  [0.8997002 1.       ]]
# array([ 5., 30.])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn-whitegrid')
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression

import csv
row_list = [['Semester','Student','Books'],
           [1,36,31],
           [2,26,20],
           [3,35,34],
           [4,39,35],
           [5,26,20],
           [6,30,30],
           [7,31,30],
           [8,38,38],
           [9,36,34],
           [10,38,33],
           [11,26,20],
           [12,26,20]]

with open('book_predict1.csv','w',newline='') as file:
    writer = csv.writer(file)
    writer.writerows(row_list)
# duplicated values for 'Student' and 'Books' are dropped
    
df = pd.read_csv('book_predict1.csv')
df.drop_duplicates(subset=['Student','Books'],keep=False,inplace=True)
    
plt.scatter(df['Student'],df['Books'])
plt.ylabel('Number of books sold')
plt.xlabel('Number of registered students')

slope, intercept, r_value, p_value, std_err = stats.linregress(df['Student'],df['Books'])

line = slope*(df['Student'])+intercept
plt.plot(df['Student'], line, 'r', label='y={:.2f}x+{:.2f}'.format(slope,intercept))
plt.legend(loc='lower right')

plt.show()

print(np.corrcoef(df['Student'],df['Books']))
# Out:
# [[1.         0.76768857]
#  [0.76768857 1.        ]]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn-whitegrid')
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression

import csv
row_list = [['Semester','Student','Books'],
           [1,36,31],
           [2,26,20],
           [3,35,34],
           [4,39,35],
           [5,26,20],
           [6,30,30],
           [7,31,30],
           [8,38,38],
           [9,36,34],
           [10,38,33],
           [11,26,20],
           [12,26,20]]

with open('book_predict2.csv','w',newline='') as file:
    writer = csv.writer(file)
    writer.writerows(row_list)

    
df = pd.read_csv('book_predict2.csv')
# duplicated pairs for 'Student' and 'Books' are not dropped
    
plt.scatter(df['Student'],df['Books'])
plt.ylabel('Number of books sold')
plt.xlabel('Number of registered students')

slope, intercept, r_value, p_value, std_err = stats.linregress(df['Student'],df['Books'])

line = slope*(df['Student'])+intercept
plt.plot(df['Student'], line, 'r', label='y={:.2f}x+{:.2f}'.format(slope,intercept))
plt.legend(loc='lower right')

plt.show()

print(np.corrcoef(df['Student'],df['Books']))
# Out:
# [[1.         0.94505347]
#  [0.94505347 1.        ]]
